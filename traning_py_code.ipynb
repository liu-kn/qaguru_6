# %%
condition = 18

if condition > 18:
    print("Suсcess")
else:
    print("Failed")
# Out:
# Failed

# %%
import random

x = random.randint(-10, 10)
print(x)
if x > 0:
    print("Positive")
else:
    print("Negative")
# Out:
# -6
# Negative

# %%
import random

x = random.randint(-10, 10)
x = 0
print(x)
if x > 0:
    print("Positive")
elif x == 0:
    print("Zero")
else:
    print("Negative")
# Out:
# 0
# Zero

# %%
map = random.randint(0, 100)

print(map)

if map >= 90:
    print("A")
elif map >= 75:
    print("B")
elif map >= 60:
    print("C")
else:
    print("D")
# Out:
# 16
# D

# %%
name = input("Name: ").strip()
if name:
    print(f"Your name is {name}")
else:
    print("Error")
# Out:
# Your name is Luba

# %%
name = input("Name: ").strip()
if name:
    if name != "-":
        print(f"Your name is {name}")
    else:
        print("Error")
else:
    print("Error")
# Out:
# Error

# %%
age = 5
had_id = True

if age >=18 and had_id == True:
    print("ok")
else:
    print("Error")
# Out:
# Error

# %%
if not True:
    print("ok")
if not False:
    print("ok")
# Out:
# ok

# %%
user_list = [1, 2, 3]

if user_list:
    print("ok")
# Out:
# ok

# %%
a, b, c, d = 1000, -1, True, 10

if a>= b >= c <= d:
    print("ok")

# %%
s1 = "hello"
s2 = "he" + "llo"
if s1 == s2:
    print("ok")
if s1 is s2:
        print("ok")
# Out:
# ok
# ok

# %%
a = [1, 2]
b = a
c = a.copy()

if a is b:
    print("ok a == b")
if a is c:
    print("ok c == a")
# Out:
# ok a == b

# %%
condition = True
result = '' if condition else pass

# %%
x = 3
result = "четное" if x % 2 == 0 else "нечетное"
print(result)
# Out:
# нечетное
