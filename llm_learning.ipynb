# %%
email = {
    "body": "Привет"
}

# %%
email = {
    "body": "Привет, коллега!"
}
def add_exclamation(email: dict) -> dict:
    email["body"] = email["body"] + "!"
    return(email)

# %%
def normalize_subject(email: dict) -> dict:
    email["subject"] = email["subject"].strip()
    return email

# %%
email = {
    "subject": "  Hello  ",
    "body": "Hi\n\tBob"
}

def pipeline(email: dict) -> dict:
    ...
    def normalize_subject(email) -> dict:
        email["subject"] = email["subject"].strip()
        return email

    def clean_body(email) -> dict:
        email["body"] = email["body"].replace("\n", " ")
        return email

    def add_short(email) -> dict:
        email["short"] = email["body"][:5] + "..."
        return email
