# %%
def say_hello_world(name: str):
    print(f"Hello, {name.capitalize()}!")

say_hello_world('uba')
# Out:
# Hello, Uba!

# %%
def say_hello_world(name: str):
    text = f"Hello, {name.capitalize()}!"
    return text


text = say_hello_world('uba')
print(text)

text = say_hello_world('oleg')
print(text)
# Out:
# Hello, Uba!
# Hello, Oleg!

# %%
def square(number):
    return number * number

result = square(1)
print(result)

result = square(2)
print(result)

result = square(3)
print(result)
# Out:
# 1
# 4
# 9
